# %% [markdown]
#  解决二分类问题使用的是 对数几率回归
#  多分类问题使用的是 soft——max函数 技术i对数回归在n个可能性上不同值得推广
#  [详情见连接](https://blog.csdn.net/github_38325884/article/details/117735281)

# %% [markdown]
# ## 使用torchvision加载数据集

# %%
import torchvision
from torchvision.transforms import ToTensor
import torch.utils.data.dataloader

# %%
train_ds = torchvision.datasets.MNIST('./data',train=True,transform=ToTensor(),download=True)
test_ds = torchvision.datasets.MNIST('./data',train=False,transform=ToTensor(),download=True)

# %%
train_dl = torch.utils.data.DataLoader(train_ds,batch_size=64,shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds,batch_size=64,shuffle=True)

# %%
imgs,labels = next(iter(test_dl))

# %%
imgs[1].shape
# Out:
# torch.Size([1, 28, 28])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10,1))
for i,img in enumerate(imgs[:10]):
    npimg = img.numpy()
    npimg = np.squeeze(npimg)
    plt.subplot(1,10,i+1)
    plt.imshow(npimg)
    plt.axis("off")

# %%
labels[:10]
# Out:
# tensor([8, 6, 2, 4, 9, 7, 0, 9, 6, 7])

# %% [markdown]
# ## 创建多层感知器模型

# %%
from torch import nn

# %%
nn.Linear() #要求输入数据是一维的
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 nn.Linear()
#
# TypeError: __init__() missing 2 required positional arguments: 'in_features' and 'out_features'

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(28*28,120)
        self.linear2 = nn.Linear(120,84)
        self.linear3 = nn.Linear(84,10)
    def forward(self,input):
        x = input.view(-1,1*28*28)
        x = torch.relu(self.linear1(x))
        x = torch.relu(self.linear2(x))
        logits = self.linear3(x)
        return logits

# %%
loss_fn = torch.nn.CrossEntropyLoss()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = Model().to(device)
opt = torch.optim.SGD(model.parameters(),lr=0.001)

# %%
def train(dl,model,loss_fn,optimizer):
    size = len(dl.dataset)
    num_batches = len(dl)
    
    train_loss,correct = 0,0
    for x,y in dl:
        x,y = x.to(device),y.to(device)
        pred = model(x)
        # loss_fn返回的是这个批次的平均损失
        loss = loss_fn(pred,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        with torch.no_grad():
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            train_loss += loss.item()
    correct /= size
    train_loss /= num_batches
    return correct,train_loss

# %%
def test(test_dl,model,loss_fn):
    size = len(test_dl.dataset)
    num_batches = len(test_dl)
    
    test_loss,correct = 0,0
    with torch.no_grad():
        for x,y in test_dl:
            x,y = x.to(device),y.to(device)
            pred = model(x)
            # loss_fn返回的是这个批次的平均损失
            loss = loss_fn(pred,y)
            test_loss = loss_fn(pred,y)
            test_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    correct /= size
    test_loss /= num_batches
    return correct,test_loss

# %%
epoches = 50
train_loss = []
train_acc = []
test_loss = []
test_acc = []

for epoch in range(epoches):
    epoch_acc,epoch_loss = train(train_dl,model,loss_fn,opt)
    epoch_test_acc,epoch_test_loss = test(test_dl,model,loss_fn)
    train_acc.append(epoch_acc)
    train_loss.append(epoch_loss)
    test_acc.append(epoch_test_acc)
    test_loss.append(epoch_test_loss)
    
    template = ("epoch:{:2d},train_loss:{:.5f},train_acc:{:.1f},test_loss:{:.5f},test_acc:{:.1f}")
    print(template.format(epoch,epoch_loss,epoch_acc*100,epoch_test_loss,epoch_test_acc*100))
print("done")
# Out:
# epoch: 0,train_loss:2.29149,train_acc:11.1,test_loss:0.02927,test_acc:14.3
# epoch: 1,train_loss:2.26312,train_acc:25.1,test_loss:0.02878,test_acc:35.9
# epoch: 2,train_loss:2.21919,train_acc:44.5,test_loss:0.02816,test_acc:52.8
# epoch: 3,train_loss:2.14079,train_acc:54.5,test_loss:0.02638,test_acc:57.9
# epoch: 4,train_loss:2.00196,train_acc:58.2,test_loss:0.02431,test_acc:61.0
# epoch: 5,train_loss:1.78292,train_acc:62.8,test_loss:0.02112,test_acc:67.3
# epoch: 6,train_loss:1.49627,train_acc:68.9,test_loss:0.01758,test_acc:72.7
# epoch: 7,train_loss:1.20644,train_acc:74.1,test_loss:0.01096,test_acc:77.8
# epoch: 8,train_loss:0.98467,train_acc:78.2,test_loss:0.01071,test_acc:80.3
# epoch: 9,train_loss:0.83631,train_acc:80.5,test_loss:0.00882,test_acc:82.2
# epoch:10,train_loss:0.73656,train_acc:82.0,test_loss:0.00867,test_acc:83.3
# epoch:11,train_loss:0.66623,train_acc:83.2,test_loss:0.00897,test_acc:84.2
# ...

# %%
plt.plot(range(epoches),train_loss,label="train_loss")
# plt.plot(range(epoches),test_loss.cpu().numpy(),label="test_loss")
plt.plot(range(epoches),train_acc,label="train_acc")
plt.plot(range(epoches),test_acc,label="test_acc")
plt.legend()
test_loss
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 plt.plot(range(epoches),train_loss,label="train_loss")
#       2 # plt.plot(range(epoches),test_loss.cpu().numpy(),label="test_loss")
#       3 plt.plot(range(epoches),train_acc,label="train_acc")
#
# File D:\software\miniconda\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File D:\software\miniconda\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
# ...

# %%
def fit(epoches,train_dl,test_dl,loss_fn,opt): 
    epoches = 50
    train_loss = []
    train_acc = []
    test_loss = []
    test_acc = []

    for epoch in range(epoches):
        epoch_acc,epoch_loss = train(train_dl,model,loss_fn,opt)
        epoch_test_acc,epoch_test_loss = test(test_dl,model,loss_fn)
        train_acc.append(epoch_acc)
        train_loss.append(epoch_loss)
        test_acc.append(epoch_test_acc)
        test_loss.append(epoch_test_loss)

        template = ("epoch:{:2d},train_loss:{:.5f},train_acc:{:.1f},test_loss:{:.5f},test_acc:{:.1f}")
        print(template.format(epoch,epoch_loss,epoch_acc,epoch_test_loss,epoch_test_acc))
    print("done")
    return train_loss,train_acc,test_loss,test_acc

# %%
# Totensor 将输入转换为tensor 将图片格式
